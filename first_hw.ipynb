# %% [markdown]
# ## Условие 2:
# **На складе лежат разные фрукты в разном количестве.
# Нужно написать функцию, которая на вход принимает любое количество названий фруктов и их количество,
# а возвращает общее количество фруктов на складе**

# %%
def any_fruits(*args):
    return sum(args)

print(any_fruits())
# Out:
# 0

# %% [markdown]
# ## Условие 2:
# **На складе лежат разные фрукты в разном количестве.
# Нужно написать функцию, которая на вход принимает любое количество названий фруктов и их количество,
# а возвращает общее количество фруктов на складе**

# %%
def any_fruits(**kwargs):
    total_fruits = 0
    for fruit,qua in kwargs.items():
        total_fruits += qua
    return total_fruits

print(any_fruits())
# Out:
# 0

# %% [markdown]
# ## Условие 3:
# **Дан список с затратами на рекламу.
# Но в данных есть ошибки, некоторые затраты имеют отрицательную величину.
# Удалите такие значения из списка и посчитайте суммарные затраты
# [100, 125, -90, 345, 655, -1, 0, 200]**
# * Используйте list comprehensions

# %%
advertisement = [100,125,-90,345,655,-1,0,200]
accurate_advertisement = [advertisement[i] for i in range(len(advertisement)) if advertisement[i] >= 0]
print(sum(accurate_advertisement))
# Out:
# 1425

# %% [markdown]
# ### Условие 4.1:
# *Даны два списка.*
#
# * Дата покупки
#
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30',
# '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18',
# '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20',
# '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09',
# '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
#
#
# * Суммы покупок по датам
#
# [1270, 8413, 9028, 3703, 5739, 4095,
# 295, 4944, 5723, 3701, 4471, 651,
# 7037, 4274, 6275, 4988, 6930, 2971,
# 6592, 2004, 2822, 519, 3406, 2732,
# 5015, 2008, 316, 6333, 5700, 2887]
# ### 4.1 Найдите, какая выручка у компании в ноябре
# * Используйте list comprehensions

# %%
data = [
    '2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30',
    '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18',
    '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20',
    '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09',
    '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09'
]

purchases = [
    1270, 8413, 9028, 3703, 5739, 4095,
    295, 4944, 5723, 3701, 4471, 651,
    7037, 4274, 6275, 4988, 6930, 2971,
    6592, 2004, 2822, 519, 3406, 2732,
    5015, 2008, 316, 6333, 5700, 2887
]

print(sum([purchases[i] for i in range(len(data)) if data[i].startswith('2021-11')]))
# Out:
# 25098

# %% [markdown]
# ### 4.2 Найдите выручку компании в зависимости от месяца
# **Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой,
# а на выходе словарь, где ключи - это месяцы, а значения - это выручка.**
# * Используйте аннотирование типов.

# %%
from datetime import datetime

def revenue_by_month(data: list[str], purchases: list[float]) -> dict[str,float]:
    
    return dict(zip(data,purchases))

def monthly_revenue(dates: list[str], revenue: list[float]) -> dict[str, float]:
    revenue_by_month = {}

    for date, purchases in zip(dates, revenue):
        month = datetime.strptime(date, '%Y-%m-%d').strftime('%B')
        if month not in revenue_by_month:
            revenue_by_month[month] = 0
        revenue_by_month[month] += purchases

    return revenue_by_month


data = [
    '2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30',
    '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18',
    '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20',
    '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09',
    '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09'
]

purchases = [
    1270, 8413, 9028, 3703, 5739, 4095,
    295, 4944, 5723, 3701, 4471, 651,
    7037, 4274, 6275, 4988, 6930, 2971,
    6592, 2004, 2822, 519, 3406, 2732,
    5015, 2008, 316, 6333, 5700, 2887
]


revenue_data = revenue_by_month(data,purchases)
print(revenue_data)
print()
print(monthly_revenue(data,purchases))
# Out:
# {'2021-09-14': 1270, '2021-12-15': 8413, '2021-09-08': 9028, '2021-12-05': 3703, '2021-10-09': 2732, '2021-09-30': 2008, '2021-12-22': 295, '2021-11-29': 4944, '2021-12-24': 5723, '2021-11-26': 3701, '2021-10-27': 4471, '2021-12-18': 651, '2021-11-09': 316, '2021-11-23': 4274, '2021-09-27': 6275, '2021-10-02': 4988, '2021-12-27': 6930, '2021-09-20': 2971, '2021-12-13': 6333, '2021-11-01': 2004, '2021-12-06': 519, '2021-12-08': 3406, '2021-10-31': 5015, '2021-10-26': 5700, '2021-12-09': 2887}
#
# {'September': 25647, 'December': 45452, 'October': 28645, 'November': 25098}
